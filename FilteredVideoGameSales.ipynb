# %%
import csv
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
save_folder =(r"C:\Users\RAC\Documents\charts")
save_folder
# Out:
# 'C:\\Users\\RAC\\Documents\\charts'

# %%
df = pd.read_csv(r"C:\Users\RAC\Documents\videogames-filtered.csv")

df
# Out:
#                              Name         Genre Platform  \
# 0                      Wii Sports        Sports      Wii
# 1               Super Mario Bros.      Platform      NES
# 2                  Mario Kart Wii        Racing      Wii
# 3               Wii Sports Resort        Sports      Wii
# 4        Pokemon Red/Pokemon Blue  Role-Playing       GB
# ...                           ...           ...      ...
# 2360                Grand Kingdom  Role-Playing      PSV
# 2361  Guilty Gear Xrd -Revelator-      Fighting      PS3
# 2362     Odin Sphere: Leifthrasir  Role-Playing      PS3
# 2363             Natural Doctrine  Role-Playing      PS3
# 2364         Smash Court Tennis 3        Sports      PSP
#
#                  Publisher    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 Nintendo  2006.0     41.49     29.02      3.77         8.46
# 1                 Nintendo  1985.0     29.08      3.58      6.81         0.77
# ...

# %%
sales_df = df[["Name","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]]
sales_df
# Out:
#                              Name  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                      Wii Sports     41.49     29.02      3.77         8.46
# 1               Super Mario Bros.     29.08      3.58      6.81         0.77
# 2                  Mario Kart Wii     15.85     12.88      3.79         3.31
# 3               Wii Sports Resort     15.75     11.01      3.28         2.96
# 4        Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
# ...                           ...       ...       ...       ...          ...
# 2360                Grand Kingdom      0.01      0.02      0.04         0.01
# 2361  Guilty Gear Xrd -Revelator-      0.01      0.02      0.02         0.01
# 2362     Odin Sphere: Leifthrasir      0.01      0.02      0.03         0.01
# 2363             Natural Doctrine      0.03      0.01      0.01         0.01
# 2364         Smash Court Tennis 3      0.01      0.01      0.01         0.01
#
#       Global_Sales
# 0            82.74
# ...

# %%
games_by_company_df = df.groupby(['Platform','Year'],as_index=False)['Name'].count()
games_by_company_df
# Out:
#     Platform    Year  Name
# 0        3DS  2011.0    32
# 1        3DS  2012.0    27
# 2        3DS  2013.0    17
# 3        3DS  2014.0    13
# 4        3DS  2015.0    22
# ..       ...     ...   ...
# 149       XB  2005.0     1
# 150     XOne  2013.0     2
# 151     XOne  2014.0     7
# 152     XOne  2015.0    11
# 153     XOne  2016.0     1
#
# [154 rows x 3 columns]

# %%
games_on_platform_df = df.groupby(['Publisher'],as_index=False)['Name'].count()
games_on_platform_df
# Out:
#                                   Publisher  Name
# 0                                 505 Games    14
# 1                               989 Studios     1
# 2                            AQ Interactive     1
# 3                       ASCII Entertainment     3
# 4                     Acclaim Entertainment     5
# ..                                      ...   ...
# 103  Warner Bros. Interactive Entertainment    32
# 104                      Xing Entertainment     1
# 105                             Xseed Games     2
# 106                        Yacht Club Games     1
# 107                  Zoo Digital Publishing     1
#
# [108 rows x 2 columns]

# %%
genre_perYear_df = df.groupby(['Genre','Year'],as_index=False)['Name'].count()
genre_perYear_df
# Out:
#         Genre    Year  Name
# 0      Action  1984.0     1
# 1      Action  1985.0     1
# 2      Action  1986.0     4
# 3      Action  1988.0     1
# 4      Action  1989.0     1
# ..        ...     ...   ...
# 305  Strategy  2009.0     6
# 306  Strategy  2010.0     4
# 307  Strategy  2011.0     2
# 308  Strategy  2013.0     1
# 309  Strategy  2015.0     1
#
# [310 rows x 3 columns]

# %%
platform_yearlysales_df = df.groupby(['Platform','Year'],as_index=False)['Global_Sales'].sum()
platform_yearlysales_df
# Out:
#     Platform    Year  Global_Sales
# 0        3DS  2011.0         49.02
# 1        3DS  2012.0         39.19
# 2        3DS  2013.0         41.21
# 3        3DS  2014.0         29.67
# 4        3DS  2015.0         18.24
# ..       ...     ...           ...
# 149       XB  2005.0          0.44
# 150     XOne  2013.0          3.72
# 151     XOne  2014.0         16.06
# 152     XOne  2015.0         25.73
# 153     XOne  2016.0          0.51
#
# [154 rows x 3 columns]

# %%
platform_sales_df = df.groupby(['Platform'],as_index=False)['Global_Sales'].sum()
platform_sales_df
# Out:
#    Platform  Global_Sales
# 0       3DS        179.24
# 1        DC          6.55
# 2        DS        406.58
# 3        GB        225.91
# 4       GBA        134.03
# 5        GC        100.50
# 6       GEN         19.62
# 7       N64        137.77
# 8       NES        201.63
# 9        PS        323.57
# 10      PS2        543.97
# 11      PS3        676.18
# 12      PS4        229.60
# 13      PSP        105.69
# 14      PSV         31.93
# 15      SAT          4.16
# 16      SCD          1.50
# 17     SNES        112.61
# 18      Wii        493.44
# 19     WiiU         63.96
# 20     X360        582.25
# 21       XB         32.80
# 22     XOne         46.02

# %%
platform_sales_df.plot.bar(x='Platform', y='Global_Sales')
plt.legend(loc="best")
plt.title("Amount of Games Sold On Each Gaming Console")
plt.xlabel("Console")
plt.ylabel("Sales")
plt.grid()

plt.savefig(save_folder + "/platform_sales_chart.png")
plt.show()

# %%
genre_sales_df = df.groupby(['Genre'],as_index=False)['Global_Sales'].sum()
genre_sales_df
# Out:
#            Genre  Global_Sales
# 0         Action        923.75
# 1      Adventure         82.39
# 2       Fighting        240.25
# 3           Misc        282.87
# 4       Platform        592.07
# 5         Puzzle        133.98
# 6         Racing        393.00
# 7   Role-Playing        607.17
# 8        Shooter        668.53
# 9     Simulation        154.70
# 10        Sports        542.87
# 11      Strategy         37.93

# %%
genre_sales_df.plot(x='Genre', y='Global_Sales',figsize=(20,20))
plt.xticks(ticks=np.arange(12),labels=genre_sales_df['Genre'])
plt.legend()
plt.title("Amount of Games Sold In Each Genre")
plt.xlabel("Genres")
plt.ylabel("Sales")
plt.grid()

plt.savefig(save_folder + "/genre_sales_chart.png")
plt.show()

# %%
year_sales_df = df.groupby(['Year'],as_index=False)['Global_Sales'].sum()
year_sales_df
# Out:
#       Year  Global_Sales
# 0   1983.0          8.82
# 1   1984.0         45.33
# 2   1985.0         49.44
# 3   1986.0         22.37
# 4   1987.0         10.61
# 5   1988.0         39.38
# 6   1989.0         69.29
# 7   1990.0         43.07
# 8   1991.0         24.57
# 9   1992.0         57.97
# 10  1993.0         26.05
# 11  1994.0         33.33
# 12  1995.0         32.78
# 13  1996.0        116.05
# 14  1997.0        102.61
# 15  1998.0        121.25
# 16  1999.0        134.14
# 17  2000.0        105.89
# 18  2001.0        181.29
# 19  2002.0        181.48
# 20  2003.0        126.88
# 21  2004.0        166.30
# 22  2005.0        225.63
# 23  2006.0        322.56
# 24  2007.0        296.83
# 25  2008.0        299.09
# 26  2009.0        336.23
# 27  2010.0        327.49
# 28  2011.0        285.30
# 29  2012.0        229.28
# 30  2013.0        246.88
# 31  2014.0        195.78
# 32  2015.0        161.64
# 33  2016.0         33.90

# %%
year_sales_df.plot.scatter(x='Year', y='Global_Sales')
plt.title("Global Videogame Sales from 1984 to 2016")
plt.savefig(save_folder + "/year_sales_chart.png")
plt.show()
